# %% [markdown]
# https://www.premierleague.com/stats/top/players/goals?se=489

# %%
import pandas as pd

# %%
pd.read_html('https://www.premierleague.com/stats/top/players/goals?se=489')
# Out:
# [    Rank                   Player               Club        Nationality  Stat  \
#  0      1             Alan Shearer                  -            England   260
#  1      2             Wayne Rooney                  -            England   208
#  2      3               Harry Kane  Tottenham Hotspur            England   192
#  3      4              Andrew Cole                  -            England   187
#  4      5            Sergio Agüero                  -          Argentina   184
#  5      6            Frank Lampard                  -            England   177
#  6      7            Thierry Henry                  -             France   175
#  7      8            Robbie Fowler                  -            England   163
#  8      9            Jermain Defoe                  -            England   162
#  9     10             Michael Owen                  -            England   150
#  10    11            Les Ferdinand                  -            England   149
# ...

# %%
table_list=pd.read_html('https://www.premierleague.com/stats/top/players/goals?se=489')

# %%
table_list[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         20 non-null     int64
#  1   Player       20 non-null     object
#  2   Club         20 non-null     object
#  3   Nationality  20 non-null     object
#  4   Stat         20 non-null     int64
#  5   Unnamed: 5   0 non-null      float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.1+ KB

# %%
table_list[0]
# Out:
#     Rank                   Player               Club        Nationality  Stat  \
# 0      1             Alan Shearer                  -            England   260
# 1      2             Wayne Rooney                  -            England   208
# 2      3               Harry Kane  Tottenham Hotspur            England   192
# 3      4              Andrew Cole                  -            England   187
# 4      5            Sergio Agüero                  -          Argentina   184
# 5      6            Frank Lampard                  -            England   177
# 6      7            Thierry Henry                  -             France   175
# 7      8            Robbie Fowler                  -            England   163
# 8      9            Jermain Defoe                  -            England   162
# 9     10             Michael Owen                  -            England   150
# 10    11            Les Ferdinand                  -            England   149
# ...

# %%
scorers_df=table_list[0]

# %%
scorers_df
# Out:
#     Rank                   Player               Club        Nationality  Stat  \
# 0      1             Alan Shearer                  -            England   260
# 1      2             Wayne Rooney                  -            England   208
# 2      3               Harry Kane  Tottenham Hotspur            England   192
# 3      4              Andrew Cole                  -            England   187
# 4      5            Sergio Agüero                  -          Argentina   184
# 5      6            Frank Lampard                  -            England   177
# 6      7            Thierry Henry                  -             France   175
# 7      8            Robbie Fowler                  -            England   163
# 8      9            Jermain Defoe                  -            England   162
# 9     10             Michael Owen                  -            England   150
# 10    11            Les Ferdinand                  -            England   149
# ...

# %%
scorers_df.drop(['Rank','Club','Nationality','Unnamed: 5'],axis=1)
# Out:
#                      Player  Stat
# 0              Alan Shearer   260
# 1              Wayne Rooney   208
# 2                Harry Kane   192
# 3               Andrew Cole   187
# 4             Sergio Agüero   184
# 5             Frank Lampard   177
# 6             Thierry Henry   175
# 7             Robbie Fowler   163
# 8             Jermain Defoe   162
# 9              Michael Owen   150
# 10            Les Ferdinand   149
# 11         Teddy Sheringham   146
# 12         Robin van Persie   144
# 13              Jamie Vardy   133
# 14  Jimmy Floyd Hasselbaink   127
# 15             Robbie Keane   126
# 16           Nicolas Anelka   125
# 17            Mohamed Salah   123
# 18             Dwight Yorke   123
# 19            Romelu Lukaku   121

# %%
scorers_df2 = scorers_df.drop(['Rank','Club','Nationality','Unnamed: 5'],axis=1)

# %%
scorers_df2.rename(columns={'Stat':'Goals Scored'})
# Out:
#                      Player  Goals Scored
# 0              Alan Shearer           260
# 1              Wayne Rooney           208
# 2                Harry Kane           192
# 3               Andrew Cole           187
# 4             Sergio Agüero           184
# 5             Frank Lampard           177
# 6             Thierry Henry           175
# 7             Robbie Fowler           163
# 8             Jermain Defoe           162
# 9              Michael Owen           150
# 10            Les Ferdinand           149
# 11         Teddy Sheringham           146
# 12         Robin van Persie           144
# 13              Jamie Vardy           133
# 14  Jimmy Floyd Hasselbaink           127
# 15             Robbie Keane           126
# 16           Nicolas Anelka           125
# 17            Mohamed Salah           123
# 18             Dwight Yorke           123
# 19            Romelu Lukaku           121

# %%
scorers_df3 = scorers_df2.rename(columns={'Stat':'Goals Scored'})

# %%
scorers_df3.to_csv('Goalscorers.csv')
